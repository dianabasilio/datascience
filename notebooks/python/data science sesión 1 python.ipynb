# %%
# Importacion de librerias
import pandas as pd
from sklearn.preprocessing import StandardScaler

# %%
# Carga de datos
#df = pd.read_csv("https://github.com/DeaAnalytics/univ-workshop/raw/main/data/Medidas_Centrales_U.csv")
df = pd.read_csv("https://github.com/dianabasilio/datascience/raw/main/data/Medidas_Centrales_U.csv")
df
# Out:
#             id         hotel  stays_in_weekend_nights  stays_in_week_nights  \
# 0            1  Resort Hotel                        0                     0
# 1            2  Resort Hotel                        0                     0
# 2            3  Resort Hotel                        0                     1
# 3            4  Resort Hotel                        0                     1
# 4            5  Resort Hotel                        0                     2
# ...        ...           ...                      ...                   ...
# 119385  119386    City Hotel                        2                     5
# 119386  119387    City Hotel                        2                     5
# 119387  119388    City Hotel                        2                     5
# 119388  119389    City Hotel                        2                     5
# 119389  119390    City Hotel                        2                     7
#
#         adults  children market_segment  agent  company  days_in_waiting_list  \
# 0            2       0.0         Direct    NaN      NaN                     0
# 1            2       0.0         Direct    NaN      NaN                     0
# 2            1       0.0         Direct    NaN      NaN                     0
# 3            1       0.0      Corporate  304.0      NaN                     0
# 4            2       0.0      Online TA  240.0      NaN                     0
# ...        ...       ...            ...    ...      ...                   ...
# 119385       2       0.0  Offline TA/TO  394.0      NaN                     0
# 119386       3       0.0      Online TA    9.0      NaN                     0
# 119387       2       0.0      Online TA    9.0      NaN                     0
# 119388       2       0.0      Online TA   89.0      NaN                     0
# 119389       2       0.0      Online TA    9.0      NaN                     0
#
#        customer_type     adr
# 0          Transient    0.00
# 1          Transient    0.00
# 2          Transient   75.00
# 3          Transient   75.00
# 4          Transient   98.00
# ...              ...     ...
# 119385     Transient   96.14
# 119386     Transient  225.43
# 119387     Transient  157.71
# 119388     Transient  104.40
# 119389     Transient  151.20
#
# [119390 rows x 12 columns]

# %%
#Obtenemos la media de la tabla llamada "df" de la variable llamada "adults"
df['adults'].mean()
# Out:
# 1.8564033838679956

# %%
#Obtenemos la media de la tabla llamada "df" de la variable llamada "hotel" pero sale ERROR porque esta variable es tipo char
df['hotel'].mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1426         try:
# -> 1427             x = float(x)
#    1428         except ValueError:
#
# ValueError: could not convert string to float: 'Resort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelReso ...
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1430             try:
# -> 1431                 x = complex(x)
#    1432             except ValueError as err:
#
# ValueError: complex() arg is a malformed string
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f6fe9fde1396> in <module>
#       1 #Obtenemos la media de la tabla llamada "df" de la variable llamada "hotel" pero sale ERROR porque esta variable es tipo char
# ----> 2 df['hotel'].mean()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11466         if level is not None:
#   11467             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11468         return self._reduce(
#   11469             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11470         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4234                 )
#    4235             with np.errstate(all="ignore"):
# -> 4236                 return op(delegate, skipna=skipna, **kwds)
#    4237
#    4238     def _reindex_indexer(self, new_index, indexer, copy):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      69             try:
#      70                 with np.errstate(invalid="ignore"):
# ---> 71                     return f(*args, **kwargs)
#      72             except ValueError as e:
#      73                 # we want to transform an object array
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     127                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     128             else:
# --> 129                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     130
#     131             return result
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in nanmean(values, axis, skipna, mask)
#     561         dtype_count = dtype
#     562     count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 563     the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     564
#     565     if axis is not None and getattr(the_sum, "ndim", False):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/nanops.py in _ensure_numeric(x)
#    1432             except ValueError as err:
#    1433                 # e.g. "foo"
# -> 1434                 raise TypeError(f"Could not convert {x} to numeric") from err
#    1435     return x
#    1436
#
# TypeError: Could not convert Resort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort HotelResort Hote ...

# %%
#Obtenemos la mediana de la tabla llamada "df" de la variable llamada "adults"
df['adults'].median()
# Out:
# 2.0

# %%
#Obtenemos la moda de la tabla llamada "df" de la variable llamada "adults"
df['adults'].mode()
# Out:
# 0    2
# dtype: int64

# %%
#Obtenemos la moda de la tabla llamada "df" de la variable llamada "hotel"
df['hotel'].mode()
# Out:
# 0    City Hotel
# dtype: object

# %%
#Hacemos un summary que nos proporciona información rápida con un panorama general del comportamiento de mis variables dentro de la tabla MCU
df.describe()
# Out:
#                   id  stays_in_weekend_nights  stays_in_week_nights  \
# count  119390.000000            119390.000000         119390.000000
# mean    59695.500000                 0.927599              2.500302
# std     34465.068657                 0.998613              1.908286
# min         1.000000                 0.000000              0.000000
# 25%     29848.250000                 0.000000              1.000000
# 50%     59695.500000                 1.000000              2.000000
# 75%     89542.750000                 2.000000              3.000000
# max    119390.000000                19.000000             50.000000
#
#               adults       children          agent      company  \
# count  119390.000000  119386.000000  103050.000000  6797.000000
# mean        1.856403       0.103890      86.693382   189.266735
# std         0.579261       0.398561     110.774548   131.655015
# min         0.000000       0.000000       1.000000     6.000000
# 25%         2.000000       0.000000       9.000000    62.000000
# 50%         2.000000       0.000000      14.000000   179.000000
# 75%         2.000000       0.000000     229.000000   270.000000
# max        55.000000      10.000000     535.000000   543.000000
#
#        days_in_waiting_list            adr
# count         119390.000000  119390.000000
# mean               2.321149     101.831122
# std               17.594721      50.535790
# min                0.000000      -6.380000
# 25%                0.000000      69.290000
# 50%                0.000000      94.575000
# 75%                0.000000     126.000000
# max              391.000000    5400.000000

# %%
#Obtenemos una tabla con todas las variables del data frame "df" y contabiliza cuántos NULL tenemos en cada variable
df.isnull().sum()
# Out:
# id                              0
# hotel                           0
# stays_in_weekend_nights         0
# stays_in_week_nights            0
# adults                          0
# children                        4
# market_segment                  0
# agent                       16340
# company                    112593
# days_in_waiting_list            0
# customer_type                   0
# adr                             0
# dtype: int64

# %%
#Voy a eliminar aquella(s) variable(s)/(columnas) que contienen muchos NULL y que no son de utilidad para mi estudio, en este caso "company"
df_clean = df.drop("company", axis=1).copy()
df_clean
# Out:
#             id         hotel  stays_in_weekend_nights  stays_in_week_nights  \
# 0            1  Resort Hotel                        0                     0
# 1            2  Resort Hotel                        0                     0
# 2            3  Resort Hotel                        0                     1
# 3            4  Resort Hotel                        0                     1
# 4            5  Resort Hotel                        0                     2
# ...        ...           ...                      ...                   ...
# 119385  119386    City Hotel                        2                     5
# 119386  119387    City Hotel                        2                     5
# 119387  119388    City Hotel                        2                     5
# 119388  119389    City Hotel                        2                     5
# 119389  119390    City Hotel                        2                     7
#
#         adults  children market_segment  agent  days_in_waiting_list  \
# 0            2       0.0         Direct    NaN                     0
# 1            2       0.0         Direct    NaN                     0
# 2            1       0.0         Direct    NaN                     0
# 3            1       0.0      Corporate  304.0                     0
# 4            2       0.0      Online TA  240.0                     0
# ...        ...       ...            ...    ...                   ...
# 119385       2       0.0  Offline TA/TO  394.0                     0
# 119386       3       0.0      Online TA    9.0                     0
# 119387       2       0.0      Online TA    9.0                     0
# 119388       2       0.0      Online TA   89.0                     0
# 119389       2       0.0      Online TA    9.0                     0
#
#        customer_type     adr
# 0          Transient    0.00
# 1          Transient    0.00
# 2          Transient   75.00
# 3          Transient   75.00
# 4          Transient   98.00
# ...              ...     ...
# 119385     Transient   96.14
# 119386     Transient  225.43
# 119387     Transient  157.71
# 119388     Transient  104.40
# 119389     Transient  151.20
#
# [119390 rows x 11 columns]

# %%
#Si deseo reemplazar/sustituir algún NULL, por ejemplo reemplazar los NULL por ceros en la variable "children"
#df_clean["children"] = df_clean["children"].fillna(0)
df_clean["children"].fillna(0, inplace=True)
df_clean
# Out:
#             id         hotel  stays_in_weekend_nights  stays_in_week_nights  \
# 0            1  Resort Hotel                        0                     0
# 1            2  Resort Hotel                        0                     0
# 2            3  Resort Hotel                        0                     1
# 3            4  Resort Hotel                        0                     1
# 4            5  Resort Hotel                        0                     2
# ...        ...           ...                      ...                   ...
# 119385  119386    City Hotel                        2                     5
# 119386  119387    City Hotel                        2                     5
# 119387  119388    City Hotel                        2                     5
# 119388  119389    City Hotel                        2                     5
# 119389  119390    City Hotel                        2                     7
#
#         adults  children market_segment  agent  days_in_waiting_list  \
# 0            2       0.0         Direct    NaN                     0
# 1            2       0.0         Direct    NaN                     0
# 2            1       0.0         Direct    NaN                     0
# 3            1       0.0      Corporate  304.0                     0
# 4            2       0.0      Online TA  240.0                     0
# ...        ...       ...            ...    ...                   ...
# 119385       2       0.0  Offline TA/TO  394.0                     0
# 119386       3       0.0      Online TA    9.0                     0
# 119387       2       0.0      Online TA    9.0                     0
# 119388       2       0.0      Online TA   89.0                     0
# 119389       2       0.0      Online TA    9.0                     0
#
#        customer_type     adr
# 0          Transient    0.00
# 1          Transient    0.00
# 2          Transient   75.00
# 3          Transient   75.00
# 4          Transient   98.00
# ...              ...     ...
# 119385     Transient   96.14
# 119386     Transient  225.43
# 119387     Transient  157.71
# 119388     Transient  104.40
# 119389     Transient  151.20
#
# [119390 rows x 11 columns]

# %%
#Hago lo mismo que en el paso anterior para la variable "days_in_waiting_list"
# df_clean["days_in_waiting_list"] = df_clean["days_in_waiting_list"].fillna(0)
df_clean["days_in_waiting_list"].fillna(0, inplace=True)
df_clean
# Out:
#             id         hotel  stays_in_weekend_nights  stays_in_week_nights  \
# 0            1  Resort Hotel                        0                     0
# 1            2  Resort Hotel                        0                     0
# 2            3  Resort Hotel                        0                     1
# 3            4  Resort Hotel                        0                     1
# 4            5  Resort Hotel                        0                     2
# ...        ...           ...                      ...                   ...
# 119385  119386    City Hotel                        2                     5
# 119386  119387    City Hotel                        2                     5
# 119387  119388    City Hotel                        2                     5
# 119388  119389    City Hotel                        2                     5
# 119389  119390    City Hotel                        2                     7
#
#         adults  children market_segment  agent  days_in_waiting_list  \
# 0            2       0.0         Direct    NaN                     0
# 1            2       0.0         Direct    NaN                     0
# 2            1       0.0         Direct    NaN                     0
# 3            1       0.0      Corporate  304.0                     0
# 4            2       0.0      Online TA  240.0                     0
# ...        ...       ...            ...    ...                   ...
# 119385       2       0.0  Offline TA/TO  394.0                     0
# 119386       3       0.0      Online TA    9.0                     0
# 119387       2       0.0      Online TA    9.0                     0
# 119388       2       0.0      Online TA   89.0                     0
# 119389       2       0.0      Online TA    9.0                     0
#
#        customer_type     adr
# 0          Transient    0.00
# 1          Transient    0.00
# 2          Transient   75.00
# 3          Transient   75.00
# 4          Transient   98.00
# ...              ...     ...
# 119385     Transient   96.14
# 119386     Transient  225.43
# 119387     Transient  157.71
# 119388     Transient  104.40
# 119389     Transient  151.20
#
# [119390 rows x 11 columns]

# %%
#Elimino todas las filas que contengan algún NULL
# df_clean = df_clean.dropna()
df_clean.dropna(inplace=True)
df_clean
# Out:
#             id         hotel  stays_in_weekend_nights  stays_in_week_nights  \
# 3            4  Resort Hotel                        0                     1
# 4            5  Resort Hotel                        0                     2
# 5            6  Resort Hotel                        0                     2
# 7            8  Resort Hotel                        0                     2
# 8            9  Resort Hotel                        0                     3
# ...        ...           ...                      ...                   ...
# 119385  119386    City Hotel                        2                     5
# 119386  119387    City Hotel                        2                     5
# 119387  119388    City Hotel                        2                     5
# 119388  119389    City Hotel                        2                     5
# 119389  119390    City Hotel                        2                     7
#
#         adults  children market_segment  agent  days_in_waiting_list  \
# 3            1       0.0      Corporate  304.0                     0
# 4            2       0.0      Online TA  240.0                     0
# 5            2       0.0      Online TA  240.0                     0
# 7            2       0.0         Direct  303.0                     0
# 8            2       0.0      Online TA  240.0                     0
# ...        ...       ...            ...    ...                   ...
# 119385       2       0.0  Offline TA/TO  394.0                     0
# 119386       3       0.0      Online TA    9.0                     0
# 119387       2       0.0      Online TA    9.0                     0
# 119388       2       0.0      Online TA   89.0                     0
# 119389       2       0.0      Online TA    9.0                     0
#
#        customer_type     adr
# 3          Transient   75.00
# 4          Transient   98.00
# 5          Transient   98.00
# 7          Transient  103.00
# 8          Transient   82.00
# ...              ...     ...
# 119385     Transient   96.14
# 119386     Transient  225.43
# 119387     Transient  157.71
# 119388     Transient  104.40
# 119389     Transient  151.20
#
# [103050 rows x 11 columns]

# %%
#Contabilizamos cuantos NULL tiene nuestra tabla
df_clean.isnull().sum()
# Out:
# id                         0
# hotel                      0
# stays_in_weekend_nights    0
# stays_in_week_nights       0
# adults                     0
# children                   0
# market_segment             0
# agent                      0
# days_in_waiting_list       0
# customer_type              0
# adr                        0
# dtype: int64

# %%
#NUESTRA TABLA HA QUEDADO LISTA SIN NULL!

#Ahora vamos a normalizar los datos,
#para ajustar los valores medios en diferentes escalas respecto a una escala común
#ya que hay variabes que contienen datos muy grandes respecto a otra
#Normalizamos las columnas 8 y 11 (agent y adr) que son las que tienen datos que son muy grandes respecto al resto y lo renombramos como "Normal"
df_normal = df_clean.copy()

scaler = StandardScaler()
df_normal[["agent", "adr"]] = scaler.fit_transform(df_normal[["agent", "adr"]])

df_normal
# Out:
#             id         hotel  stays_in_weekend_nights  stays_in_week_nights  \
# 3            4  Resort Hotel                        0                     1
# 4            5  Resort Hotel                        0                     2
# 5            6  Resort Hotel                        0                     2
# 7            8  Resort Hotel                        0                     2
# 8            9  Resort Hotel                        0                     3
# ...        ...           ...                      ...                   ...
# 119385  119386    City Hotel                        2                     5
# 119386  119387    City Hotel                        2                     5
# 119387  119388    City Hotel                        2                     5
# 119388  119389    City Hotel                        2                     5
# 119389  119390    City Hotel                        2                     7
#
#         adults  children market_segment     agent  days_in_waiting_list  \
# 3            1       0.0      Corporate  1.961711                     0
# 4            2       0.0      Online TA  1.383958                     0
# 5            2       0.0      Online TA  1.383958                     0
# 7            2       0.0         Direct  1.952684                     0
# 8            2       0.0      Online TA  1.383958                     0
# ...        ...       ...            ...       ...                   ...
# 119385       2       0.0  Offline TA/TO  2.774176                     0
# 119386       3       0.0      Online TA -0.701368                     0
# 119387       2       0.0      Online TA -0.701368                     0
# 119388       2       0.0      Online TA  0.020823                     0
# 119389       2       0.0      Online TA -0.701368                     0
#
#        customer_type       adr
# 3          Transient -0.591971
# 4          Transient -0.132286
# 5          Transient -0.132286
# 7          Transient -0.032354
# 8          Transient -0.452067
# ...              ...       ...
# 119385     Transient -0.169460
# 119386     Transient  2.414571
# 119387     Transient  1.061098
# 119388     Transient -0.004373
# 119389     Transient  0.930987
#
# [103050 rows x 11 columns]
